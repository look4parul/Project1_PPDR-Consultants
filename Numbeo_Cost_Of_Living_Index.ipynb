# %%
import pandas as pd
import requests
import config
import pprint
import numpy

# %%
api_key = config.api_key
api_key
# Out:
# 'mq5wkztko2o9tg'

# %%
def get_coli_json(api_key):
    url = "https://www.numbeo.com/api/rankings_by_city_current"
    r = requests.get(url, params={"api_key": api_key, "section":"1"})
    if r.status_code == 200:
        r_json = r.json()
        return r_json
    else:
        return None

# %%
response = get_coli_json(api_key)

# %%
pprint.pprint(response)
# Out:
# [{'city_id': 6379,
#   'city_name': 'Zurich',
#   'country': 'Switzerland',
#   'cpi_and_rent_index': 96.3819390249294,
#   'cpi_index': 128.19699307966363,
#   'groceries_index': 127.77436269625481,
#   'purchasing_power_incl_rent_index': 126.94457717313658,
#   'rent_index': 61.65620463799534,
#   'restaurant_price_index': 124.73642667360008},
#  {'city_id': 6348,
#   'city_name': 'Basel',
#   'country': 'Switzerland',
#   'cpi_and_rent_index': 87.34575761243138,
#   'cpi_index': 125.44892977587625,
#   'groceries_index': 124.8129136699497,
#   'purchasing_power_incl_rent_index': 121.50291541028034,
#   'rent_index': 45.75662079779462,
#   'restaurant_price_index': 123.11306897749161},
#  {'city_id': 6360,
#   'city_name': 'Lausanne',
#   'country': 'Switzerland',
#   'cpi_and_rent_index': 88.62968089214505,
#   'cpi_index': 123.92429954907038,
#   'groceries_index': 127.0736480546839,
#   'purchasing_power_incl_rent_index': 110.86926234551694,
#   'rent_index': 50.10604517365921,
#   'restaurant_price_index': 123.64036714227488},
#  {'city_id': 6355,
#   'city_name': 'Geneva',
#   'country': 'Switzerland',
#   'cpi_and_rent_index': 94.78684553914603,
#   'cpi_index': 118.89769512150335,
#   'groceries_index': 112.71746550356802,
#   'purchasing_power_incl_rent_index': 109.88099864628555,
#   'rent_index': 68.47015417034193,
#   'restaurant_price_index': 119.58425698453325},
#  {'city_id': 6349,
#   'city_name': 'Bern',
#   'country': 'Switzerland',
#   'cpi_and_rent_index': 79.85697955184382,
#   'cpi_index': 116.34532234526465,
#   'groceries_index': 107.42705992932302,
#   'purchasing_power_incl_rent_index': 131.96082286919713,
#   'rent_index': 40.030408838374186,
#   'restaurant_price_index': 115.56041450122297},
#  {'city_id': 7409,
#   'city_name': 'Stavanger',
#   'country': 'Norway',
#   'cpi_and_rent_index': 70.59810148381563,
#   'cpi_index': 102.20126166716324,
#   'groceries_index': 90.86593371255196,
#   'purchasing_power_incl_rent_index': 87.61057415504362,
#   'rent_index': 36.10364661265205,
#   'restaurant_price_index': 112.45772586514697},
#  {'city_id': 5968,
#   'city_name': 'Oslo',
#   'country': 'Norway',
#   'cpi_and_rent_index': 74.09995432920226,
#   'cpi_index': 101.61735720396725,
#   'groceries_index': 89.21338977179455,
#   'purchasing_power_incl_rent_index': 85.94099055575222,
#   'rent_index': 44.06505256215177,
#   'restaurant_price_index': 112.05578531125724},
#  {'city_id': 5970,
#   'city_name': 'Trondheim',
#   'country': 'Norway',
#   'cpi_and_rent_index': 70.94524913496338,
#   'cpi_index': 101.48543082461465,
#   'groceries_index': 95.40049325966416,
#   'purchasing_power_incl_rent_index': 89.34201415497337,
#   'rent_index': 37.611022021628465,
#   'restaurant_price_index': 102.74955710465761},
#  {'city_id': 5582,
#   'city_name': 'Reykjavik',
#   'country': 'Iceland',
#   'cpi_and_rent_index': 76.69850131539471,
#   'cpi_index': 100.27634932117013,
#   'groceries_index': 84.35034292576086,
#   'purchasing_power_incl_rent_index': 81.09645037810546,
#   'rent_index': 50.963574514532496,
#   'restaurant_price_index': 120.15015481295154},
#  {'city_id': 5955,
#   'city_name': 'Bergen',
#   'country': 'Norway',
#   'cpi_and_rent_index': 69.09708935212466,
#   'cpi_index': 100.11010247230585,
#   'groceries_index': 88.29454708914626,
#   'purchasing_power_incl_rent_index': 93.31218460324638,
#   'rent_index': 35.24677263422302,
#   'restaurant_price_index': 111.5760104070883},
#  {'city_id': 3455,
#   'city_name': 'New York, NY',
#   'country': 'United States',
#   'cpi_and_rent_index': 100,
#   'cpi_index': 100,
#   'groceries_index': 100,
#   'purchasing_power_incl_rent_index': 100,
#   'rent_index': 100,
#   'restaurant_price_index': 100},
#  {'city_id': 3483,
#   'city_name': 'San Francisco, CA',
#   'country': 'United States',
#   'cpi_and_rent_index': 102.91623071387099,
#   'cpi_index': 91.46633975002747,
#   'groceries_index': 86.7859109168398,
#   'purchasing_power_incl_rent_index': 136.04482291148648,
#   'rent_index': 115.41364378397769,
#   'restaurant_price_index': 94.45792779190465},
#  {'city_id': 3389,
#   'city_name': 'Anchorage, AK',
#   'country': 'United States',
#   'cpi_and_rent_index': 66.26030377130748,
#   'cpi_index': 91.29435175350302,
#   'groceries_index': 88.29480263928237,
#   'purchasing_power_incl_rent_index': 118.48154211884008,
#   'rent_index': 38.93595287239313,
#   'restaurant_price_index': 78.88648347092882},
#  {'city_id': 3427,
#   'city_name': 'Honolulu, HI',
#   'country': 'United States',
#   'cpi_and_rent_index': 76.91482512285891,
#   'cpi_index': 89.63370465948633,
#   'groceries_index': 89.70311927797374,
#   'purchasing_power_incl_rent_index': 88.32833031185041,
#   'rent_index': 63.032326865006304,
#   'restaurant_price_index': 83.60120999244441},
#  {'city_id': 9925,
#   'city_name': 'Brooklyn, NY',
#   'country': 'United States',
#   'cpi_and_rent_index': 84.80558990323695,
#   'cpi_index': 88.75858345538823,
#   'groceries_index': 83.09467488589894,
#   'purchasing_power_incl_rent_index': 92.98302625877572,
#   'rent_index': 80.49094678211857,
#   'restaurant_price_index': 92.77485207067625},
#  {'city_id': 3497,
#   'city_name': 'Washington, DC',
#   'country': 'United States',
#   'cpi_and_rent_index': 83.1390873782839,
#   'cpi_index': 87.6785704605267,
#   'groceries_index': 86.3182093897218,
#   'purchasing_power_incl_rent_index': 130.29585230852095,
#   'rent_index': 78.18429825560169,
#   'restaurant_price_index': 87.48250316697062},
#  {'city_id': 5246,
#   'city_name': 'Aalborg',
#   'country': 'Denmark',
#   'cpi_and_rent_index': 57.189939725437945,
#   'cpi_index': 87.45617709980353,
#   'groceries_index': 74.90374661645617,
#   'purchasing_power_incl_rent_index': 116.72221860003312,
#   'rent_index': 24.154719412879054,
#   'restaurant_price_index': 99.71390200198317},
#  {'city_id': 4164,
#   'city_name': 'Tokyo',
#   'country': 'Japan',
#   'cpi_and_rent_index': 63.51030441653821,
#   'cpi_index': 86.85956865863072,
#   'groceries_index': 83.35464093944496,
#   'purchasing_power_incl_rent_index': 89.73935876138796,
#   'rent_index': 38.02487394056554,
#   'restaurant_price_index': 56.68638173560245},
#  {'city_id': 6845,
#   'city_name': 'Tel Aviv-Yafo',
#   'country': 'Israel',
#   'cpi_and_rent_index': 66.68244041234045,
#   'cpi_index': 86.26886092420634,
#   'groceries_index': 72.84825396685942,
#   'purchasing_power_incl_rent_index': 74.62757796318972,
#   'rent_index': 45.30410690029534,
#   'restaurant_price_index': 93.72994354685666},
#  {'city_id': 3459,
#   'city_name': 'Oakland, CA',
#   'country': 'United States',
#   'cpi_and_rent_index': 82.95272785367868,
#   'cpi_index': 86.22345850029585,
#   'groceries_index': 89.15004897141515,
#   'purchasing_power_incl_rent_index': 114.91662032838018,
#   'rent_index': 79.3827661779816,
#   'restaurant_price_index': 74.61603660435696},
#  {'city_id': 5248,
#   'city_name': 'Copenhagen',
#   'country': 'Denmark',
#   'cpi_and_rent_index': 65.96346142257636,
#   'cpi_index': 85.86819605594536,
#   'groceries_index': 62.352232146217425,
#   'purchasing_power_incl_rent_index': 90.65639260615377,
#   'rent_index': 44.23769202009049,
#   'restaurant_price_index': 104.34790243289653},
#  {'city_id': 3487,
#   'city_name': 'Seattle, WA',
#   'country': 'United States',
#   'cpi_and_rent_index': 76.19627219007108,
#   'cpi_index': 85.54970570146823,
#   'groceries_index': 81.56691015384507,
#   'purchasing_power_incl_rent_index': 133.3833763512763,
#   'rent_index': 65.98711626143951,
#   'restaurant_price_index': 80.8789203311023},
#  {'city_id': 5426,
#   'city_name': 'Paris',
#   'country': 'France',
#   'cpi_and_rent_index': 66.69538424722205,
#   'cpi_index': 85.0211178465591,
#   'groceries_index': 78.71285817722794,
#   'purchasing_power_incl_rent_index': 71.24752377175247,
#   'rent_index': 46.69307476437536,
#   'restaurant_price_index': 81.44737324164191},
#  {'city_id': 4724,
#   'city_name': 'Seoul',
#   'country': 'South Korea',
#   'cpi_and_rent_index': 58.77054241799653,
#   'cpi_index': 85.01140165336766,
#   'groceries_index': 103.12132169474617,
#   'purchasing_power_incl_rent_index': 77.03227236917375,
#   'rent_index': 30.12897209959477,
#   'restaurant_price_index': 45.693987457847676},
#  {'city_id': 5796,
#   'city_name': 'Luxembourg',
#   'country': 'Luxembourg',
#   'cpi_and_rent_index': 70.22606604494817,
#   'cpi_index': 83.49657776444029,
#   'groceries_index': 69.29865459936453,
#   'purchasing_power_incl_rent_index': 106.34884990595685,
#   'rent_index': 55.74146814494221,
#   'restaurant_price_index': 92.27069887675796},
#  {'city_id': 3400,
#   'city_name': 'Boston, MA',
#   'country': 'United States',
#   'cpi_and_rent_index': 78.79356401688834,
#   'cpi_index': 82.79950698457152,
#   'groceries_index': 81.10870251421676,
#   'purchasing_power_incl_rent_index': 112.47732271449004,
#   'rent_index': 74.42112726962866,
#   'restaurant_price_index': 81.85446301275378},
#  {'city_id': 9978,
#   'city_name': 'Bellevue, WA',
#   'country': 'United States',
#   'cpi_and_rent_index': 73.09658017100216,
#   'cpi_index': 82.1230123826324,
#   'groceries_index': 76.75224623608393,
#   'purchasing_power_incl_rent_index': 163.32912327459914,
#   'rent_index': 63.24434207945331,
#   'restaurant_price_index': 76.62133388112929},
#  {'city_id': 6512,
#   'city_name': 'London',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 76.17966087276503,
#   'cpi_index': 81.60335496682545,
#   'groceries_index': 57.53539817115354,
#   'purchasing_power_incl_rent_index': 77.97822504057709,
#   'rent_index': 70.25976646735856,
#   'restaurant_price_index': 89.38290292801943},
#  {'city_id': 4673,
#   'city_name': 'Singapore',
#   'country': 'Singapore',
#   'cpi_and_rent_index': 72.3566769722985,
#   'cpi_index': 80.96876325394221,
#   'groceries_index': 66.6775537245432,
#   'purchasing_power_incl_rent_index': 89.2082735634194,
#   'rent_index': 62.956692291486135,
#   'restaurant_price_index': 59.01377204016357},
#  {'city_id': 5247,
#   'city_name': 'Arhus',
#   'country': 'Denmark',
#   'cpi_and_rent_index': 57.07580194808002,
#   'cpi_index': 80.86834683678124,
#   'groceries_index': 62.21399638491684,
#   'purchasing_power_incl_rent_index': 100.85208290233277,
#   'rent_index': 31.106536179339322,
#   'restaurant_price_index': 88.56257897626901},
#  {'city_id': 6830,
#   'city_name': 'Haifa',
#   'country': 'Israel',
#   'cpi_and_rent_index': 52.10580168889265,
#   'cpi_index': 80.16791916078961,
#   'groceries_index': 63.328064799507075,
#   'purchasing_power_incl_rent_index': 83.82943945650142,
#   'rent_index': 21.476350738171142,
#   'restaurant_price_index': 88.23746377422596},
#  {'city_id': 3405,
#   'city_name': 'Chicago, IL',
#   'country': 'United States',
#   'cpi_and_rent_index': 69.85077714426285,
#   'cpi_index': 80.12587071607665,
#   'groceries_index': 76.35673561862563,
#   'purchasing_power_incl_rent_index': 111.90351981346043,
#   'rent_index': 58.635640763798214,
#   'restaurant_price_index': 76.66810218972293},
#  {'city_id': 4152,
#   'city_name': 'Osaka',
#   'country': 'Japan',
#   'cpi_and_rent_index': 52.33171044201674,
#   'cpi_index': 79.53255452837188,
#   'groceries_index': 77.59627938772066,
#   'purchasing_power_incl_rent_index': 85.85397057900428,
#   'rent_index': 22.64232864124568,
#   'restaurant_price_index': 45.51470057090909},
#  {'city_id': 7417,
#   'city_name': 'Jerusalem',
#   'country': 'Israel',
#   'cpi_and_rent_index': 56.905959497939165,
#   'cpi_index': 79.29855290959178,
#   'groceries_index': 60.883267269677134,
#   'purchasing_power_incl_rent_index': 71.2628309653114,
#   'rent_index': 32.464723292277334,
#   'restaurant_price_index': 90.15500947240581},
#  {'city_id': 10048,
#   'city_name': 'Sarasota, FL',
#   'country': 'United States',
#   'cpi_and_rent_index': 63.540075358344204,
#   'cpi_index': 79.20379227513571,
#   'groceries_index': 89.16500682020592,
#   'purchasing_power_incl_rent_index': 81.83177834703137,
#   'rent_index': 46.44332385734564,
#   'restaurant_price_index': 71.72685208167748},
#  {'city_id': 5601,
#   'city_name': 'Dublin',
#   'country': 'Ireland',
#   'cpi_and_rent_index': 70.68585928935937,
#   'cpi_index': 78.95813892761767,
#   'groceries_index': 60.26105453062288,
#   'purchasing_power_incl_rent_index': 76.60873102353484,
#   'rent_index': 61.65676931835381,
#   'restaurant_price_index': 82.37513894405465},
#  {'city_id': 3581,
#   'city_name': 'Sydney',
#   'country': 'Australia',
#   'cpi_and_rent_index': 66.40384241677543,
#   'cpi_index': 78.79880183604257,
#   'groceries_index': 70.72282180495026,
#   'purchasing_power_incl_rent_index': 96.92031424873933,
#   'rent_index': 52.87489892386792,
#   'restaurant_price_index': 69.98309002367611},
#  {'city_id': 3465,
#   'city_name': 'Philadelphia, PA',
#   'country': 'United States',
#   'cpi_and_rent_index': 63.52332509492719,
#   'cpi_index': 78.78160115930115,
#   'groceries_index': 77.3515007397955,
#   'purchasing_power_incl_rent_index': 100.26996706427826,
#   'rent_index': 46.8691072236513,
#   'restaurant_price_index': 72.84840475594183},
#  {'city_id': 3484,
#   'city_name': 'San Jose, CA',
#   'country': 'United States',
#   'cpi_and_rent_index': 80.85948174276223,
#   'cpi_index': 78.58308283251418,
#   'groceries_index': 71.28503801177214,
#   'purchasing_power_incl_rent_index': 143.53270895259868,
#   'rent_index': 83.34414273940816,
#   'restaurant_price_index': 83.18296401601953},
#  {'city_id': 3469,
#   'city_name': 'Portland, OR',
#   'country': 'United States',
#   'cpi_and_rent_index': 64.63256946005477,
#   'cpi_index': 78.56876472828134,
#   'groceries_index': 75.84471668117428,
#   'purchasing_power_incl_rent_index': 112.85884176245511,
#   'rent_index': 49.42138627563173,
#   'restaurant_price_index': 68.95633787952474},
#  {'city_id': 3454,
#   'city_name': 'New Orleans, LA',
#   'country': 'United States',
#   'cpi_and_rent_index': 60.65626734514501,
#   'cpi_index': 78.40249326529411,
#   'groceries_index': 77.30686674477649,
#   'purchasing_power_incl_rent_index': 89.82710381035697,
#   'rent_index': 41.28648326074798,
#   'restaurant_price_index': 75.81211023771561},
#  {'city_id': 2370,
#   'city_name': 'Toronto',
#   'country': 'Canada',
#   'cpi_and_rent_index': 64.9662489830189,
#   'cpi_index': 78.30869845702347,
#   'groceries_index': 73.72858407911215,
#   'purchasing_power_incl_rent_index': 77.46882058490809,
#   'rent_index': 50.403131921885844,
#   'restaurant_price_index': 76.22455784838664},
#  {'city_id': 5931,
#   'city_name': 'Amsterdam',
#   'country': 'Netherlands',
#   'cpi_and_rent_index': 66.64634362306688,
#   'cpi_index': 78.21329841669636,
#   'groceries_index': 58.244081069667644,
#   'purchasing_power_incl_rent_index': 85.0302182968265,
#   'rent_index': 54.02115684393329,
#   'restaurant_price_index': 81.08050605500947},
#  {'city_id': 3979,
#   'city_name': 'Hong Kong',
#   'country': 'Hong Kong',
#   'cpi_and_rent_index': 78.33467653941688,
#   'cpi_index': 77.1776774446657,
#   'groceries_index': 75.83299144148022,
#   'purchasing_power_incl_rent_index': 65.35139048052166,
#   'rent_index': 79.59752660973676,
#   'restaurant_price_index': 54.38403331218035},
#  {'city_id': 3475,
#   'city_name': 'Sacramento, CA',
#   'country': 'United States',
#   'cpi_and_rent_index': 62.255029046536905,
#   'cpi_index': 76.95479005011755,
#   'groceries_index': 69.4251436797207,
#   'purchasing_power_incl_rent_index': 115.43848516758315,
#   'rent_index': 46.21042339276168,
#   'restaurant_price_index': 76.08391612822712},
#  {'city_id': 5950,
#   'city_name': 'Utrecht',
#   'country': 'Netherlands',
#   'cpi_and_rent_index': 58.180091272902146,
#   'cpi_index': 76.68076606839017,
#   'groceries_index': 57.564602992568716,
#   'purchasing_power_incl_rent_index': 81.0496322628633,
#   'rent_index': 37.98683565806331,
#   'restaurant_price_index': 84.05232196745065},
#  {'city_id': 5599,
#   'city_name': 'Cork',
#   'country': 'Ireland',
#   'cpi_and_rent_index': 59.12293172889886,
#   'cpi_index': 76.65750237937932,
#   'groceries_index': 62.26095140448832,
#   'purchasing_power_incl_rent_index': 80.71222761508898,
#   'rent_index': 39.984166729475355,
#   'restaurant_price_index': 81.51326778595018},
#  {'city_id': 3450,
#   'city_name': 'Minneapolis, MN',
#   'country': 'United States',
#   'cpi_and_rent_index': 61.635673164815294,
#   'cpi_index': 76.63674391718122,
#   'groceries_index': 67.82996934614593,
#   'purchasing_power_incl_rent_index': 127.23935266384862,
#   'rent_index': 45.262191681173185,
#   'restaurant_price_index': 78.54854195404266},
#  {'city_id': 5643,
#   'city_name': 'Milan',
#   'country': 'Italy',
#   'cpi_and_rent_index': 59.73540441542996,
#   'cpi_index': 76.58716212962288,
#   'groceries_index': 63.68643165672664,
#   'purchasing_power_incl_rent_index': 57.54321622628367,
#   'rent_index': 41.34192121312967,
#   'restaurant_price_index': 78.25014876498715},
#  {'city_id': 3442,
#   'city_name': 'Los Angeles, CA',
#   'country': 'United States',
#   'cpi_and_rent_index': 74.85615619892152,
#   'cpi_index': 76.49152334898942,
#   'groceries_index': 71.12908209508923,
#   'purchasing_power_incl_rent_index': 113.70612057312766,
#   'rent_index': 73.07117336718798,
#   'restaurant_price_index': 79.98080469105831},
#  {'city_id': 3570,
#   'city_name': 'Darwin',
#   'country': 'Australia',
#   'cpi_and_rent_index': 53.45163097820296,
#   'cpi_index': 76.03151598054754,
#   'groceries_index': 68.37516309896425,
#   'purchasing_power_incl_rent_index': 110.0112789272437,
#   'rent_index': 28.805968339064496,
#   'restaurant_price_index': 74.5012929435609},
#  {'city_id': 7382,
#   'city_name': 'Stockholm',
#   'country': 'Sweden',
#   'cpi_and_rent_index': 57.746877867699155,
#   'cpi_index': 76.01109854732407,
#   'groceries_index': 64.48586963211679,
#   'purchasing_power_incl_rent_index': 92.05669570130918,
#   'rent_index': 37.81170896891725,
#   'restaurant_price_index': 80.08941507075362},
#  {'city_id': 5259,
#   'city_name': 'Odense',
#   'country': 'Denmark',
#   'cpi_and_rent_index': 50.78743900846804,
#   'cpi_index': 75.70356747189277,
#   'groceries_index': 57.03318469377319,
#   'purchasing_power_incl_rent_index': 104.98481772984552,
#   'rent_index': 23.591795792426907,
#   'restaurant_price_index': 96.11045317729699},
#  {'city_id': 7628,
#   'city_name': 'Brighton',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 60.14909743591033,
#   'cpi_index': 75.69545604855395,
#   'groceries_index': 56.46725743662504,
#   'purchasing_power_incl_rent_index': 74.12286794728983,
#   'rent_index': 43.180441059029086,
#   'restaurant_price_index': 87.39580465888275},
#  {'city_id': 4418,
#   'city_name': 'Auckland',
#   'country': 'New Zealand',
#   'cpi_and_rent_index': 59.6171119807892,
#   'cpi_index': 75.6856385701707,
#   'groceries_index': 65.96534877558395,
#   'purchasing_power_incl_rent_index': 83.96313652473691,
#   'rent_index': 42.0785157749714,
#   'restaurant_price_index': 69.85589991044347},
#  {'city_id': 6346,
#   'city_name': 'Uppsala',
#   'country': 'Sweden',
#   'cpi_and_rent_index': 51.45214215802796,
#   'cpi_index': 75.52398519659677,
#   'groceries_index': 67.06350010383117,
#   'purchasing_power_incl_rent_index': 88.43902981706843,
#   'rent_index': 25.178025944891434,
#   'restaurant_price_index': 79.49628037719191},
#  {'city_id': 5041,
#   'city_name': 'Linz',
#   'country': 'Austria',
#   'cpi_and_rent_index': 51.891292737826475,
#   'cpi_index': 75.52062478696357,
#   'groceries_index': 65.26515991486404,
#   'purchasing_power_incl_rent_index': 81.28517376836822,
#   'rent_index': 26.10017174625609,
#   'restaurant_price_index': 79.65861238467599},
#  {'city_id': 7700,
#   'city_name': 'Albany, NY',
#   'country': 'United States',
#   'cpi_and_rent_index': 55.11885705863953,
#   'cpi_index': 75.37976491560066,
#   'groceries_index': 69.41601007060163,
#   'purchasing_power_incl_rent_index': 105.12530788494642,
#   'rent_index': 33.004329028338006,
#   'restaurant_price_index': 80.35834597443935},
#  {'city_id': 5033,
#   'city_name': 'Innsbruck',
#   'country': 'Austria',
#   'cpi_and_rent_index': 53.406471001367215,
#   'cpi_index': 75.11404149435693,
#   'groceries_index': 64.93688814241415,
#   'purchasing_power_incl_rent_index': 73.95944260420664,
#   'rent_index': 29.712928761006395,
#   'restaurant_price_index': 73.53103863343566},
#  {'city_id': 5604,
#   'city_name': 'Galway',
#   'country': 'Ireland',
#   'cpi_and_rent_index': 56.56929332587522,
#   'cpi_index': 75.05337191153171,
#   'groceries_index': 60.868477767756104,
#   'purchasing_power_incl_rent_index': 74.66115734072683,
#   'rent_index': 36.39415226691452,
#   'restaurant_price_index': 80.319701322012},
#  {'city_id': 5943,
#   'city_name': 'Haarlem',
#   'country': 'Netherlands',
#   'cpi_and_rent_index': 58.97448376071679,
#   'cpi_index': 74.93012131185253,
#   'groceries_index': 55.434152804086125,
#   'purchasing_power_incl_rent_index': 89.48247208970355,
#   'rent_index': 41.5591045310693,
#   'restaurant_price_index': 80.37925385053144},
#  {'city_id': 3568,
#   'city_name': 'Canberra',
#   'country': 'Australia',
#   'cpi_and_rent_index': 57.68211024793541,
#   'cpi_index': 74.7040845820251,
#   'groceries_index': 71.46605531751953,
#   'purchasing_power_incl_rent_index': 117.63347062901659,
#   'rent_index': 39.10283772965255,
#   'restaurant_price_index': 72.33034761731398},
#  {'city_id': 3435,
#   'city_name': 'Jacksonville, FL',
#   'country': 'United States',
#   'cpi_and_rent_index': 54.94435441351227,
#   'cpi_index': 74.51678954419305,
#   'groceries_index': 76.7900880294272,
#   'purchasing_power_incl_rent_index': 120.94529551922449,
#   'rent_index': 33.581285770465904,
#   'restaurant_price_index': 78.77915136943837},
#  {'city_id': 3396,
#   'city_name': 'Baltimore, MD',
#   'country': 'United States',
#   'cpi_and_rent_index': 59.14753088923541,
#   'cpi_index': 74.26205631658982,
#   'groceries_index': 67.86976511874215,
#   'purchasing_power_incl_rent_index': 124.89200472291193,
#   'rent_index': 42.65021504397857,
#   'restaurant_price_index': 76.70608081817618},
#  {'city_id': 7712,
#   'city_name': 'Newcastle',
#   'country': 'Australia',
#   'cpi_and_rent_index': 54.508537683301974,
#   'cpi_index': 74.25460408159005,
#   'groceries_index': 64.78797100958666,
#   'purchasing_power_incl_rent_index': 124.81467774479682,
#   'rent_index': 32.95595267891846,
#   'restaurant_price_index': 79.60719194738142},
#  {'city_id': 5031,
#   'city_name': 'Graz',
#   'country': 'Austria',
#   'cpi_and_rent_index': 48.801926821568955,
#   'cpi_index': 74.1668048739262,
#   'groceries_index': 67.62245973841473,
#   'purchasing_power_incl_rent_index': 81.44352603095228,
#   'rent_index': 21.11647903047644,
#   'restaurant_price_index': 62.467262162705715},
#  {'city_id': 3482,
#   'city_name': 'San Diego, CA',
#   'country': 'United States',
#   'cpi_and_rent_index': 70.64305843526265,
#   'cpi_index': 74.16311299938467,
#   'groceries_index': 67.49771895879505,
#   'purchasing_power_incl_rent_index': 130.2599195147314,
#   'rent_index': 66.80096281565685,
#   'restaurant_price_index': 76.77361850717503},
#  {'city_id': 3448,
#   'city_name': 'Miami, FL',
#   'country': 'United States',
#   'cpi_and_rent_index': 66.19419201097074,
#   'cpi_index': 74.107242548148,
#   'groceries_index': 67.33955278772832,
#   'purchasing_power_incl_rent_index': 100.29816517922126,
#   'rent_index': 57.557196119916654,
#   'restaurant_price_index': 78.4410310325778},
#  {'city_id': 3402,
#   'city_name': 'Buffalo, NY',
#   'country': 'United States',
#   'cpi_and_rent_index': 52.069668618490596,
#   'cpi_index': 73.8658113798829,
#   'groceries_index': 69.27839423123406,
#   'purchasing_power_incl_rent_index': 107.08661542383989,
#   'rent_index': 28.279450852722686,
#   'restaurant_price_index': 71.15297019655348},
#  {'city_id': 2371,
#   'city_name': 'Vancouver',
#   'country': 'Canada',
#   'cpi_and_rent_index': 63.26336374955016,
#   'cpi_index': 73.8088387974891,
#   'groceries_index': 73.42229679522703,
#   'purchasing_power_incl_rent_index': 89.00520282805525,
#   'rent_index': 51.75310936278207,
#   'restaurant_price_index': 70.33793848294093},
#  {'city_id': 3471,
#   'city_name': 'Reno, NV',
#   'country': 'United States',
#   'cpi_and_rent_index': 56.784706031619436,
#   'cpi_index': 73.79299199966484,
#   'groceries_index': 74.9226304845984,
#   'purchasing_power_incl_rent_index': 116.14364986184613,
#   'rent_index': 38.220374194016465,
#   'restaurant_price_index': 75.18598150892612},
#  {'city_id': 3391,
#   'city_name': 'Atlanta, GA',
#   'country': 'United States',
#   'cpi_and_rent_index': 60.86110573972151,
#   'cpi_index': 73.72380251002795,
#   'groceries_index': 69.67518623587198,
#   'purchasing_power_incl_rent_index': 140.65550777004276,
#   'rent_index': 46.82163276642727,
#   'restaurant_price_index': 69.77937191878391},
#  {'city_id': 3467,
#   'city_name': 'Pittsburgh, PA',
#   'country': 'United States',
#   'cpi_and_rent_index': 55.534050272094106,
#   'cpi_index': 73.55608285601944,
#   'groceries_index': 70.30770551972472,
#   'purchasing_power_incl_rent_index': 123.12603663684992,
#   'rent_index': 35.86322665678938,
#   'restaurant_price_index': 63.38506223340883},
#  {'city_id': 3579,
#   'city_name': 'Perth',
#   'country': 'Australia',
#   'cpi_and_rent_index': 52.37243095556809,
#   'cpi_index': 73.50948032681708,
#   'groceries_index': 64.83194636496344,
#   'purchasing_power_incl_rent_index': 101.51207860476705,
#   'rent_index': 29.30160539837306,
#   'restaurant_price_index': 74.46298675481113},
#  {'city_id': 6477,
#   'city_name': 'Bristol',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 55.97522642537916,
#   'cpi_index': 73.39732900356765,
#   'groceries_index': 56.96716858433197,
#   'purchasing_power_incl_rent_index': 91.06355158348894,
#   'rent_index': 36.95921892304188,
#   'restaurant_price_index': 84.3429858885218},
#  {'city_id': 5419,
#   'city_name': 'Lyon',
#   'country': 'France',
#   'cpi_and_rent_index': 50.02781847906365,
#   'cpi_index': 73.29393476107285,
#   'groceries_index': 66.79436331088809,
#   'purchasing_power_incl_rent_index': 83.28440549898454,
#   'rent_index': 24.63314296367351,
#   'restaurant_price_index': 69.93005540563509},
#  {'city_id': 6530,
#   'city_name': 'Reading',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 57.70651624693103,
#   'cpi_index': 73.1568012466614,
#   'groceries_index': 63.12532518862001,
#   'purchasing_power_incl_rent_index': 109.21036800729273,
#   'rent_index': 40.84272301935888,
#   'restaurant_price_index': 69.04697764346923},
#  {'city_id': 8029,
#   'city_name': 'Nashville, TN',
#   'country': 'United States',
#   'cpi_and_rent_index': 60.525982410853466,
#   'cpi_index': 73.13636246641093,
#   'groceries_index': 65.18377024015466,
#   'purchasing_power_incl_rent_index': 122.71243191710874,
#   'rent_index': 46.76190998230397,
#   'restaurant_price_index': 80.79020201082318},
#  {'city_id': 5939,
#   'city_name': 'Eindhoven',
#   'country': 'Netherlands',
#   'cpi_and_rent_index': 54.09639527245914,
#   'cpi_index': 73.07619423052321,
#   'groceries_index': 56.29984697291871,
#   'purchasing_power_incl_rent_index': 104.50714785115767,
#   'rent_index': 33.38018161457081,
#   'restaurant_price_index': 78.14122357764364},
#  {'city_id': 3412,
#   'city_name': 'Denver, CO',
#   'country': 'United States',
#   'cpi_and_rent_index': 62.9706543194157,
#   'cpi_index': 73.03861243393831,
#   'groceries_index': 64.96248180945028,
#   'purchasing_power_incl_rent_index': 130.60931248128995,
#   'rent_index': 51.98160370513063,
#   'restaurant_price_index': 77.13925497961569},
#  {'city_id': 3571,
#   'city_name': 'Gold Coast',
#   'country': 'Australia',
#   'cpi_and_rent_index': 55.40954542642357,
#   'cpi_index': 72.96070770904122,
#   'groceries_index': 65.76617424643163,
#   'purchasing_power_incl_rent_index': 107.4021912687181,
#   'rent_index': 36.25267086761821,
#   'restaurant_price_index': 76.37959035332298},
#  {'city_id': 5945,
#   'city_name': 'Leiden',
#   'country': 'Netherlands',
#   'cpi_and_rent_index': 53.292480729146384,
#   'cpi_index': 72.91770936798812,
#   'groceries_index': 55.132980603542784,
#   'purchasing_power_incl_rent_index': 86.71205342993666,
#   'rent_index': 31.87178863090809,
#   'restaurant_price_index': 73.8935628067906},
#  {'city_id': 4421,
#   'city_name': 'Christchurch',
#   'country': 'New Zealand',
#   'cpi_and_rent_index': 51.93169006874767,
#   'cpi_index': 72.87114206756986,
#   'groceries_index': 66.14947920153978,
#   'purchasing_power_incl_rent_index': 96.52146468664654,
#   'rent_index': 29.076539577156623,
#   'restaurant_price_index': 71.47057652244698},
#  {'city_id': 5116,
#   'city_name': 'Gent',
#   'country': 'Belgium',
#   'cpi_and_rent_index': 49.43145621289787,
#   'cpi_index': 72.45889182467849,
#   'groceries_index': 58.25069393902521,
#   'purchasing_power_incl_rent_index': 78.73822293662226,
#   'rent_index': 24.297297669862832,
#   'restaurant_price_index': 79.31908666457997},
#  {'city_id': 6480,
#   'city_name': 'Cambridge',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 58.0161612696432,
#   'cpi_index': 72.45883705411246,
#   'groceries_index': 53.28676065774201,
#   'purchasing_power_incl_rent_index': 78.13950871373612,
#   'rent_index': 42.25216092360406,
#   'restaurant_price_index': 82.84153099229559},
#  {'city_id': 3403,
#   'city_name': 'Charlotte, NC',
#   'country': 'United States',
#   'cpi_and_rent_index': 58.01677256430219,
#   'cpi_index': 72.34833905198089,
#   'groceries_index': 62.0764006000233,
#   'purchasing_power_incl_rent_index': 144.34578148558253,
#   'rent_index': 42.37404662884966,
#   'restaurant_price_index': 79.72615618967538},
#  {'city_id': 3565,
#   'city_name': 'Brisbane',
#   'country': 'Australia',
#   'cpi_and_rent_index': 54.43320284654796,
#   'cpi_index': 72.34296636474728,
#   'groceries_index': 66.77884387319129,
#   'purchasing_power_incl_rent_index': 117.55162424275262,
#   'rent_index': 34.884919515146684,
#   'restaurant_price_index': 70.40833388662574},
#  {'city_id': 5420,
#   'city_name': 'Marseille',
#   'country': 'France',
#   'cpi_and_rent_index': 48.43290231010644,
#   'cpi_index': 72.30723848497168,
#   'groceries_index': 68.61654978595459,
#   'purchasing_power_incl_rent_index': 68.79853924669386,
#   'rent_index': 22.374362373432206,
#   'restaurant_price_index': 69.2155328864824},
#  {'city_id': 7469,
#   'city_name': 'Halifax',
#   'country': 'Canada',
#   'cpi_and_rent_index': 51.60779220467827,
#   'cpi_index': 72.19836280609555,
#   'groceries_index': 74.45231755304833,
#   'purchasing_power_incl_rent_index': 80.08518632812499,
#   'rent_index': 29.13344140363568,
#   'restaurant_price_index': 63.304272104083395},
#  {'city_id': 5382,
#   'city_name': 'Helsinki',
#   'country': 'Finland',
#   'cpi_and_rent_index': 54.721138803658434,
#   'cpi_index': 72.16824010779236,
#   'groceries_index': 59.79025034723426,
#   'purchasing_power_incl_rent_index': 92.78818355580466,
#   'rent_index': 35.67784550398444,
#   'restaurant_price_index': 81.87906045474304},
#  {'city_id': 5636,
#   'city_name': 'Florence',
#   'country': 'Italy',
#   'cpi_and_rent_index': 51.59390284744969,
#   'cpi_index': 72.13062314820348,
#   'groceries_index': 60.74770968043994,
#   'purchasing_power_incl_rent_index': 56.07299532895429,
#   'rent_index': 29.178328977424716,
#   'restaurant_price_index': 76.77250926721597},
#  {'city_id': 7535,
#   'city_name': 'The Hague (Den Haag)',
#   'country': 'Netherlands',
#   'cpi_and_rent_index': 53.441013765026426,
#   'cpi_index': 72.12477470164835,
#   'groceries_index': 54.672503294829454,
#   'purchasing_power_incl_rent_index': 93.59261303448562,
#   'rent_index': 33.04792191241138,
#   'restaurant_price_index': 80.38487489298586},
#  {'city_id': 5111,
#   'city_name': 'Brussels',
#   'country': 'Belgium',
#   'cpi_and_rent_index': 51.98803733584539,
#   'cpi_index': 72.1036205123767,
#   'groceries_index': 60.380001770175504,
#   'purchasing_power_incl_rent_index': 94.22467675847219,
#   'rent_index': 30.03212938029814,
#   'restaurant_price_index': 81.20812688457248},
#  {'city_id': 3494,
#   'city_name': 'Tucson, AZ',
#   'country': 'United States',
#   'cpi_and_rent_index': 50.25446900398842,
#   'cpi_index': 72.07187927190712,
#   'groceries_index': 63.548092240527765,
#   'purchasing_power_incl_rent_index': 105.24348814438638,
#   'rent_index': 26.441038020306827,
#   'restaurant_price_index': 69.702078766326},
#  {'city_id': 5483,
#   'city_name': 'Munich',
#   'country': 'Germany',
#   'cpi_and_rent_index': 58.57905806440347,
#   'cpi_index': 72.05129582726974,
#   'groceries_index': 53.85897839473852,
#   'purchasing_power_incl_rent_index': 95.96077694673434,
#   'rent_index': 43.874278705988345,
#   'restaurant_price_index': 74.55336359275638},
#  {'city_id': 5942,
#   'city_name': 'Groningen',
#   'country': 'Netherlands',
#   'cpi_and_rent_index': 49.265764416086085,
#   'cpi_index': 72.04389077911684,
#   'groceries_index': 56.14494669936041,
#   'purchasing_power_incl_rent_index': 83.85977512176933,
#   'rent_index': 24.403723806196776,
#   'restaurant_price_index': 74.60581200977272},
#  {'city_id': 5422,
#   'city_name': 'Montpellier',
#   'country': 'France',
#   'cpi_and_rent_index': 48.29634607466734,
#   'cpi_index': 71.95085002065326,
#   'groceries_index': 67.1154291171268,
#   'purchasing_power_incl_rent_index': 68.21786174447362,
#   'rent_index': 22.4777502718807,
#   'restaurant_price_index': 70.93088552841682},
#  {'city_id': 3577,
#   'city_name': 'Melbourne',
#   'country': 'Australia',
#   'cpi_and_rent_index': 56.523476808510274,
#   'cpi_index': 71.88645293529979,
#   'groceries_index': 66.15070700464409,
#   'purchasing_power_incl_rent_index': 105.13778317765549,
#   'rent_index': 39.754980125968416,
#   'restaurant_price_index': 65.75377256766397},
#  {'city_id': 7998,
#   'city_name': 'Olympia, WA',
#   'country': 'United States',
#   'cpi_and_rent_index': 57.222271012296844,
#   'cpi_index': 71.83174855814332,
#   'groceries_index': 67.36558543781916,
#   'purchasing_power_incl_rent_index': 129.2357919730738,
#   'rent_index': 41.27620862572518,
#   'restaurant_price_index': 70.79489798183415},
#  {'city_id': 5433,
#   'city_name': 'Toulouse',
#   'country': 'France',
#   'cpi_and_rent_index': 47.963355568191965,
#   'cpi_index': 71.79649996192448,
#   'groceries_index': 65.35893896639745,
#   'purchasing_power_incl_rent_index': 95.40382993901659,
#   'rent_index': 21.949775946470474,
#   'restaurant_price_index': 70.71019484198351},
#  {'city_id': 2373,
#   'city_name': 'Victoria',
#   'country': 'Canada',
#   'cpi_and_rent_index': 55.971522715888625,
#   'cpi_index': 71.53698038084269,
#   'groceries_index': 70.83601155071692,
#   'purchasing_power_incl_rent_index': 89.44555708846602,
#   'rent_index': 38.982019961803886,
#   'restaurant_price_index': 69.03879286988277},
#  {'city_id': 5638,
#   'city_name': 'Genoa',
#   'country': 'Italy',
#   'cpi_and_rent_index': 46.24911561184216,
#   'cpi_index': 71.32569175947906,
#   'groceries_index': 62.89069034431598,
#   'purchasing_power_incl_rent_index': 62.77230435207917,
#   'rent_index': 18.8783457511829,
#   'restaurant_price_index': 71.87368857537138},
#  {'city_id': 6527,
#   'city_name': 'Oxford',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 59.32989862012047,
#   'cpi_index': 71.15633527156422,
#   'groceries_index': 52.659877224441466,
#   'purchasing_power_incl_rent_index': 84.93195765188516,
#   'rent_index': 46.42149063202133,
#   'restaurant_price_index': 72.81227963417044},
#  {'city_id': 5463,
#   'city_name': 'Hamburg',
#   'country': 'Germany',
#   'cpi_and_rent_index': 53.19846899254435,
#   'cpi_index': 71.14897373249882,
#   'groceries_index': 53.282748075153705,
#   'purchasing_power_incl_rent_index': 102.73864823838797,
#   'rent_index': 33.6057171261271,
#   'restaurant_price_index': 67.22421614673266},
#  {'city_id': 3408,
#   'city_name': 'Colorado Springs, CO',
#   'country': 'United States',
#   'cpi_and_rent_index': 54.223899003891106,
#   'cpi_index': 70.92196546282071,
#   'groceries_index': 69.96127041732888,
#   'purchasing_power_incl_rent_index': 112.65216703142507,
#   'rent_index': 35.99816788834468,
#   'restaurant_price_index': 59.379822643433435},
#  {'city_id': 3491,
#   'city_name': 'Tacoma, WA',
#   'country': 'United States',
#   'cpi_and_rent_index': 56.661932036893916,
#   'cpi_index': 70.82823535778513,
#   'groceries_index': 59.61891299956187,
#   'purchasing_power_incl_rent_index': 113.96786115388828,
#   'rent_index': 41.199588785183856,
#   'restaurant_price_index': 71.33046494800126},
#  {'city_id': 5106,
#   'city_name': 'Antwerp',
#   'country': 'Belgium',
#   'cpi_and_rent_index': 48.90447942757437,
#   'cpi_index': 70.79610197647112,
#   'groceries_index': 55.77945865529477,
#   'purchasing_power_incl_rent_index': 88.73369166379862,
#   'rent_index': 25.010046665518974,
#   'restaurant_price_index': 79.03085315166841},
#  {'city_id': 3476,
#   'city_name': 'Saint Louis, MO',
#   'country': 'United States',
#   'cpi_and_rent_index': 50.76559853574525,
#   'cpi_index': 70.73059130732841,
#   'groceries_index': 70.22151181517152,
#   'purchasing_power_incl_rent_index': 126.37980159409821,
#   'rent_index': 28.974058127537493,
#   'restaurant_price_index': 64.45547718843999},
#  {'city_id': 2341,
#   'city_name': 'Calgary',
#   'country': 'Canada',
#   'cpi_and_rent_index': 50.44230333077437,
#   'cpi_index': 70.53793852169181,
#   'groceries_index': 63.97995891622254,
#   'purchasing_power_incl_rent_index': 124.56182683943887,
#   'rent_index': 28.50816835253494,
#   'restaurant_price_index': 70.17496599712217},
#  {'city_id': 5401,
#   'city_name': 'Tampere',
#   'country': 'Finland',
#   'cpi_and_rent_index': 48.24803779627519,
#   'cpi_index': 70.52767728233246,
#   'groceries_index': 56.64712329643743,
#   'purchasing_power_incl_rent_index': 103.80067153740013,
#   'rent_index': 23.930089390515814,
#   'restaurant_price_index': 76.5332043433897},
#  {'city_id': 3409,
#   'city_name': 'Columbus, OH',
#   'country': 'United States',
#   'cpi_and_rent_index': 51.775098427135134,
#   'cpi_index': 70.45100624735855,
#   'groceries_index': 66.21879379312274,
#   'purchasing_power_incl_rent_index': 142.22065036815795,
#   'rent_index': 31.390578153046906,
#   'restaurant_price_index': 67.40154852021078},
#  {'city_id': 6556,
#   'city_name': 'York',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 50.91958705687283,
#   'cpi_index': 70.44427425609129,
#   'groceries_index': 54.25662849519205,
#   'purchasing_power_incl_rent_index': 98.3415410217272,
#   'rent_index': 29.608634685030456,
#   'restaurant_price_index': 77.1274526792872},
#  {'city_id': 6463,
#   'city_name': 'Aberdeen',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 49.280936240047104,
#   'cpi_index': 70.22046744375638,
#   'groceries_index': 54.59170004642272,
#   'purchasing_power_incl_rent_index': 116.31003760308745,
#   'rent_index': 26.42569929731044,
#   'restaurant_price_index': 77.95842559882266},
#  {'city_id': 5660,
#   'city_name': 'Rome',
#   'country': 'Italy',
#   'cpi_and_rent_index': 53.223464021729725,
#   'cpi_index': 70.17811192668417,
#   'groceries_index': 56.842718976810204,
#   'purchasing_power_incl_rent_index': 58.5876670091932,
#   'rent_index': 34.71767746048309,
#   'restaurant_price_index': 74.30699992190114},
#  {'city_id': 7393,
#   'city_name': 'Gothenburg',
#   'country': 'Sweden',
#   'cpi_and_rent_index': 52.14122505183146,
#   'cpi_index': 70.17431363532606,
#   'groceries_index': 61.46344033603527,
#   'purchasing_power_incl_rent_index': 89.1186992494199,
#   'rent_index': 32.45833395099729,
#   'restaurant_price_index': 77.35786045323717},
#  {'city_id': 4443,
#   'city_name': 'Wellington',
#   'country': 'New Zealand',
#   'cpi_and_rent_index': 54.93406824974695,
#   'cpi_index': 70.13619156020832,
#   'groceries_index': 63.6654280991284,
#   'purchasing_power_incl_rent_index': 106.74576971912045,
#   'rent_index': 38.34114040847096,
#   'restaurant_price_index': 63.95879559730822},
#  {'city_id': 3264,
#   'city_name': 'San Juan',
#   'country': 'Puerto Rico',
#   'cpi_and_rent_index': 47.85754435181501,
#   'cpi_index': 70.0618817730148,
#   'groceries_index': 65.8917851892906,
#   'purchasing_power_incl_rent_index': 80.02137941180956,
#   'rent_index': 23.62178720993121,
#   'restaurant_price_index': 72.10583944922293},
#  {'city_id': 6495,
#   'city_name': 'Edinburgh',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 52.62519150748102,
#   'cpi_index': 70.05442399435654,
#   'groceries_index': 53.22339086928034,
#   'purchasing_power_incl_rent_index': 89.71612140807387,
#   'rent_index': 33.60140179880697,
#   'restaurant_price_index': 86.80441182829412},
#  {'city_id': 5629,
#   'city_name': 'Bologna',
#   'country': 'Italy',
#   'cpi_and_rent_index': 48.5844460923247,
#   'cpi_index': 69.85074978842275,
#   'groceries_index': 60.05353712404434,
#   'purchasing_power_incl_rent_index': 60.466495293983414,
#   'rent_index': 25.37254105290249,
#   'restaurant_price_index': 72.57503411521813},
#  {'city_id': 7587,
#   'city_name': 'Malmo',
#   'country': 'Sweden',
#   'cpi_and_rent_index': 48.91761933921844,
#   'cpi_index': 69.79558383022572,
#   'groceries_index': 61.17230613497241,
#   'purchasing_power_incl_rent_index': 91.5534497370076,
#   'rent_index': 26.129581694923566,
#   'restaurant_price_index': 71.76404955627673},
#  {'city_id': 2364,
#   'city_name': "Saint John's",
#   'country': 'Canada',
#   'cpi_and_rent_index': 47.0274508661312,
#   'cpi_index': 69.7831343120945,
#   'groceries_index': 66.52038326988563,
#   'purchasing_power_incl_rent_index': 89.82133868072853,
#   'rent_index': 22.189906420089702,
#   'restaurant_price_index': 66.87526032746842},
#  {'city_id': 3470,
#   'city_name': 'Raleigh, NC',
#   'country': 'United States',
#   'cpi_and_rent_index': 53.90247823851975,
#   'cpi_index': 69.7570972822126,
#   'groceries_index': 70.77922064630243,
#   'purchasing_power_incl_rent_index': 145.34890412776977,
#   'rent_index': 36.597359448838546,
#   'restaurant_price_index': 66.78439465336665},
#  {'city_id': 7651,
#   'city_name': 'Heidelberg',
#   'country': 'Germany',
#   'cpi_and_rent_index': 50.03553868949409,
#   'cpi_index': 69.70017280254328,
#   'groceries_index': 50.28920091184702,
#   'purchasing_power_incl_rent_index': 92.46325818505649,
#   'rent_index': 28.57183600801538,
#   'restaurant_price_index': 69.86459796519073},
#  {'city_id': 5457,
#   'city_name': 'Frankfurt',
#   'country': 'Germany',
#   'cpi_and_rent_index': 53.59660785400554,
#   'cpi_index': 69.59733701692511,
#   'groceries_index': 48.26182002481309,
#   'purchasing_power_incl_rent_index': 104.5134468534952,
#   'rent_index': 36.132011692927094,
#   'restaurant_price_index': 64.61534283796816},
#  {'city_id': 5608,
#   'city_name': 'Limerick',
#   'country': 'Ireland',
#   'cpi_and_rent_index': 51.32862490142376,
#   'cpi_index': 69.58692025108257,
#   'groceries_index': 57.2425830734978,
#   'purchasing_power_incl_rent_index': 74.40688565832819,
#   'rent_index': 31.399923426340198,
#   'restaurant_price_index': 67.23519639099952},
#  {'city_id': 6509,
#   'city_name': 'Leicester',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 46.69608017126824,
#   'cpi_index': 69.57861616284247,
#   'groceries_index': 54.74591001219624,
#   'purchasing_power_incl_rent_index': 88.94778946443309,
#   'rent_index': 21.720077755059133,
#   'restaurant_price_index': 70.0348742641316},
#  {'city_id': 5948,
#   'city_name': 'Rotterdam',
#   'country': 'Netherlands',
#   'cpi_and_rent_index': 53.91930599527813,
#   'cpi_index': 69.49712888127243,
#   'groceries_index': 52.64687420456937,
#   'purchasing_power_incl_rent_index': 91.75055298258337,
#   'rent_index': 36.91630675677002,
#   'restaurant_price_index': 70.08294647280876},
#  {'city_id': 2344,
#   'city_name': 'Edmonton',
#   'country': 'Canada',
#   'cpi_and_rent_index': 50.060142434021905,
#   'cpi_index': 69.41240765498516,
#   'groceries_index': 61.260688828657116,
#   'purchasing_power_incl_rent_index': 108.12538738605252,
#   'rent_index': 28.937386499283157,
#   'restaurant_price_index': 70.1568578377825},
#  {'city_id': 3437,
#   'city_name': 'Kansas City, MO',
#   'country': 'United States',
#   'cpi_and_rent_index': 50.66127080176602,
#   'cpi_index': 69.12275203262594,
#   'groceries_index': 60.985085192547054,
#   'purchasing_power_incl_rent_index': 136.11513338666103,
#   'rent_index': 30.510794473506802,
#   'restaurant_price_index': 74.1617511819452},
#  {'city_id': 2365,
#   'city_name': 'Saskatoon',
#   'country': 'Canada',
#   'cpi_and_rent_index': 47.723491892195305,
#   'cpi_index': 69.08568823711482,
#   'groceries_index': 63.9979049418234,
#   'purchasing_power_incl_rent_index': 93.15217944927707,
#   'rent_index': 24.406921223511418,
#   'restaurant_price_index': 64.287708923247},
#  {'city_id': 3574,
#   'city_name': 'Hobart',
#   'country': 'Australia',
#   'cpi_and_rent_index': 50.52726327190011,
#   'cpi_index': 68.9919158026306,
#   'groceries_index': 63.82727798738035,
#   'purchasing_power_incl_rent_index': 116.124476001578,
#   'rent_index': 30.373325509416144,
#   'restaurant_price_index': 68.10230588832825},
#  {'city_id': 5880,
#   'city_name': 'Sliema',
#   'country': 'Malta',
#   'cpi_and_rent_index': 52.166882546918295,
#   'cpi_index': 68.95006066960305,
#   'groceries_index': 56.71869050145277,
#   'purchasing_power_incl_rent_index': 49.71859169224671,
#   'rent_index': 33.84825311274233,
#   'restaurant_price_index': 77.06320124520194},
#  {'city_id': 2359,
#   'city_name': 'Ottawa',
#   'country': 'Canada',
#   'cpi_and_rent_index': 52.024931242142756,
#   'cpi_index': 68.5103467386336,
#   'groceries_index': 61.672888047619715,
#   'purchasing_power_incl_rent_index': 119.74949574916664,
#   'rent_index': 34.03130599780025,
#   'restaurant_price_index': 68.42481697029841},
#  {'city_id': 5381,
#   'city_name': 'Espoo',
#   'country': 'Finland',
#   'cpi_and_rent_index': 50.2766828137066,
#   'cpi_index': 68.4668429049029,
#   'groceries_index': 53.5890204094442,
#   'purchasing_power_incl_rent_index': 115.98778865717527,
#   'rent_index': 30.422350122774183,
#   'restaurant_price_index': 79.15089074946097},
#  {'city_id': 6516,
#   'city_name': 'Manchester',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 50.450162613587345,
#   'cpi_index': 68.39303738110596,
#   'groceries_index': 52.950721063370764,
#   'purchasing_power_incl_rent_index': 88.3856222599655,
#   'rent_index': 30.865738766846924,
#   'restaurant_price_index': 76.90228091047612},
#  {'city_id': 6491,
#   'city_name': 'Dundee',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 46.86054588594402,
#   'cpi_index': 68.24095109418953,
#   'groceries_index': 55.46893278379294,
#   'purchasing_power_incl_rent_index': 91.60471383344888,
#   'rent_index': 23.524100470221867,
#   'restaurant_price_index': 80.07428325513598},
#  {'city_id': 2360,
#   'city_name': 'Regina',
#   'country': 'Canada',
#   'cpi_and_rent_index': 49.62203817792854,
#   'cpi_index': 68.06159790982743,
#   'groceries_index': 66.72267761755074,
#   'purchasing_power_incl_rent_index': 95.11924059539452,
#   'rent_index': 29.495488892162285,
#   'restaurant_price_index': 61.04452799839796},
#  {'city_id': 3411,
#   'city_name': 'Dallas, TX',
#   'country': 'United States',
#   'cpi_and_rent_index': 57.83527779772653,
#   'cpi_index': 68.01526555011812,
#   'groceries_index': 60.81513128729436,
#   'purchasing_power_incl_rent_index': 155.72870993235253,
#   'rent_index': 46.72394823205548,
#   'restaurant_price_index': 70.8930729712539},
#  {'city_id': 7577,
#   'city_name': 'Quebec City',
#   'country': 'Canada',
#   'cpi_and_rent_index': 43.67801552972464,
#   'cpi_index': 67.98185517697554,
#   'groceries_index': 69.35552392327646,
#   'purchasing_power_incl_rent_index': 110.57470243692076,
#   'rent_index': 17.150677913980903,
#   'restaurant_price_index': 59.137846104259836},
#  {'city_id': 3561,
#   'city_name': 'Adelaide',
#   'country': 'Australia',
#   'cpi_and_rent_index': 48.692971159286934,
#   'cpi_index': 67.97975562592919,
#   'groceries_index': 64.84315704879458,
#   'purchasing_power_incl_rent_index': 115.37114361513048,
#   'rent_index': 27.64168665056227,
#   'restaurant_price_index': 62.840607144831104},
#  {'city_id': 6472,
#   'city_name': 'Birmingham',
#   'country': 'United Kingdom',
#   'cpi_and_rent_index': 49.607334583076955,
#   'cpi_index': 67.92447333793851,
#   'groceries_index': 52.239640043091285,
#   'purchasing_power_incl_rent_index': 86.3595407948935,
#   'rent_index': 29.614406265694843,
#   'restaurant_price_index': 76.12843480568986},
#  {'city_id': 5442,
#   'city_name': 'Bonn',
#   'country': 'Germany',
#   'cpi_and_rent_index': 49.09814308374204,
#   'cpi_index': 67.8382522988017,
#   'groceries_index': 49.00445683945564,
#   'purchasing_power_incl_rent_index': 94.67522544459928,
#   'rent_index': 28.643547788548428,
#   'restaurant_price_index': 68.23284240562604},
#  {'city_id': 5503,
#   'city_name': 'Stuttgart',
#   'country': 'Germany',
#   'cpi_and_rent_index': 50.74967598428087,
#   'cpi_index': 67.5301092129059,
#   'groceries_index': 50.41700200129286,
#   'purchasing_power_incl_rent_index': 103.88363875990336,
#   'rent_index': 32.43404256770949,
#   'restaurant_price_index': 68.72551996926576},
#  {'city_id': 3393,
#   'city_name': 'Austin, TX',
#   'country': 'United States',
#   'cpi_and_rent_index': 59.9602974243435,
#   'cpi_index': 67.49943680262504,
#   'groceries_index': 63.56956396794017,
#   'purchasing_power_incl_rent_index': 146.48909856505088,
#   'rent_index': 51.731420896084956,
#   'restaurant_price_index': 71.32815585507191},
#  {'city_id': 3438,
#   'city_name': 'Las Vegas, NV',
#   'country': 'United States',
#   'cpi_and_rent_index': 52.501212837195396,
#   'cpi_index': 67.3850358785488,
#   'groceries_index': 55.64738830585385,
#   'purchasing_power_incl_rent_index': 127.96538406420943,
#   'rent_index': 36.25570576664377,
#   'restaurant_price_index': 76.28482931046598},
# ...
#   'cpi_index': 31.278959187358634,
#   'groceries_index': 24.41689218605274,
#   'purchasing_power_incl_rent_index': 29.86051834523468,
#   'rent_index': 10.029911004376483,
#   'restaurant_price_index': 32.24578327260657},
#  {'city_id': 7432,
#   'city_name': 'Asuncion',
#   'country': 'Paraguay',
#   'cpi_and_rent_index': 21.05856323379435,
#   'cpi_index': 31.10773828201769,
#   'groceries_index': 25.37443480102734,
#   'purchasing_power_incl_rent_index': 33.34995728303748,
#   'rent_index': 10.090014101925714,
#   'restaurant_price_index': 25.30279922770657},
#  {'city_id': 6668,
#   'city_name': 'Cairo',
#   'country': 'Egypt',
#   'cpi_and_rent_index': 19.218615329186854,
#   'cpi_index': 30.877118768065536,
#   'groceries_index': 26.328432939148716,
#   'purchasing_power_incl_rent_index': 24.52385887610429,
#   'rent_index': 6.493504346469072,
#   'restaurant_price_index': 25.394387203740322},
#  {'city_id': 4375,
#   'city_name': 'Kathmandu',
#   'country': 'Nepal',
#   'cpi_and_rent_index': 18.623911428452,
#   'cpi_index': 30.72357378690061,
#   'groceries_index': 26.796011262003315,
#   'purchasing_power_incl_rent_index': 21.07379908235021,
#   'rent_index': 5.417280991545756,
#   'restaurant_price_index': 21.29225813058256},
#  {'city_id': 7428,
#   'city_name': 'Zaporizhzhya',
#   'country': 'Ukraine',
#   'cpi_and_rent_index': 17.946322161224458,
#   'cpi_index': 30.286800222990085,
#   'groceries_index': 25.216592114679397,
#   'purchasing_power_incl_rent_index': 30.848489297362708,
#   'rent_index': 4.47684438999646,
#   'restaurant_price_index': 19.601109768377338},
#  {'city_id': 7414,
#   'city_name': 'Medellin',
#   'country': 'Colombia',
#   'cpi_and_rent_index': 20.636406935067395,
#   'cpi_index': 30.252194342467202,
#   'groceries_index': 25.688536734017394,
#   'purchasing_power_incl_rent_index': 30.334918231260037,
#   'rent_index': 10.140895003636219,
#   'restaurant_price_index': 23.6531595604507},
#  {'city_id': 4020,
#   'city_name': 'Gurgaon',
#   'country': 'India',
#   'cpi_and_rent_index': 20.270889269183723,
#   'cpi_index': 30.12360397782557,
#   'groceries_index': 28.09347879428567,
#   'purchasing_power_incl_rent_index': 91.61985786754202,
#   'rent_index': 9.516774145760792,
#   'restaurant_price_index': 23.5678299426574},
#  {'city_id': 8436,
#   'city_name': 'Pristina',
#   'country': 'Kosovo (Disputed Territory)',
#   'cpi_and_rent_index': 19.3070876257707,
#   'cpi_index': 28.9915642082003,
#   'groceries_index': 27.063751997683166,
#   'purchasing_power_incl_rent_index': 52.49882404734956,
#   'rent_index': 8.73660231716913,
#   'restaurant_price_index': 23.158694912240975},
#  {'city_id': 4040,
#   'city_name': 'Mumbai',
#   'country': 'India',
#   'cpi_and_rent_index': 24.929949543628645,
#   'cpi_index': 28.66845771611965,
#   'groceries_index': 26.688776898346212,
#   'purchasing_power_incl_rent_index': 41.646619393312285,
#   'rent_index': 20.84941453721439,
#   'restaurant_price_index': 26.547292595637533},
#  {'city_id': 2412,
#   'city_name': 'Cali',
#   'country': 'Colombia',
#   'cpi_and_rent_index': 18.42561371273246,
#   'cpi_index': 28.647188859065924,
#   'groceries_index': 22.75293289711336,
#   'purchasing_power_incl_rent_index': 36.240908866722506,
#   'rent_index': 7.268892025665452,
#   'restaurant_price_index': 20.52557952820235},
#  {'city_id': 6654,
#   'city_name': 'Alexandria',
#   'country': 'Egypt',
#   'cpi_and_rent_index': 17.25141949044354,
#   'cpi_index': 28.54243653530883,
#   'groceries_index': 26.062717236293643,
#   'purchasing_power_incl_rent_index': 20.33960134726516,
#   'rent_index': 4.927415319845802,
#   'restaurant_price_index': 21.409592225880147},
#  {'city_id': 7556,
#   'city_name': 'Chandigarh',
#   'country': 'India',
#   'cpi_and_rent_index': 17.636608617257334,
#   'cpi_index': 28.224993602039156,
#   'groceries_index': 29.120474576733486,
#   'purchasing_power_incl_rent_index': 46.004141545580914,
#   'rent_index': 6.079518570024796,
#   'restaurant_price_index': 19.21523617120803},
#  {'city_id': 3941,
#   'city_name': 'Tbilisi',
#   'country': 'Georgia',
#   'cpi_and_rent_index': 19.884892817395077,
#   'cpi_index': 28.197901442241367,
#   'groceries_index': 22.12366843861322,
#   'purchasing_power_incl_rent_index': 26.693748166033103,
#   'rent_index': 10.81134766590575,
#   'restaurant_price_index': 26.41093244331234},
#  {'city_id': 1831,
#   'city_name': 'Tunis',
#   'country': 'Tunisia',
#   'cpi_and_rent_index': 17.736453102461574,
#   'cpi_index': 28.126498484484536,
#   'groceries_index': 26.1118110471531,
#   'purchasing_power_incl_rent_index': 34.329774368494505,
#   'rent_index': 6.395848255975977,
#   'restaurant_price_index': 16.50159729626489},
#  {'city_id': 4016,
#   'city_name': 'Delhi',
#   'country': 'India',
#   'cpi_and_rent_index': 18.509494719313512,
#   'cpi_index': 28.005805560048618,
#   'groceries_index': 25.934741283726158,
#   'purchasing_power_incl_rent_index': 54.74974422624202,
#   'rent_index': 8.14438996909672,
#   'restaurant_price_index': 24.640678122883656},
#  {'city_id': 7146,
#   'city_name': 'Damascus',
#   'country': 'Syria',
#   'cpi_and_rent_index': 18.2078008108275,
#   'cpi_index': 27.68321257503597,
#   'groceries_index': 23.98119581407397,
#   'purchasing_power_incl_rent_index': 10.824343264132894,
#   'rent_index': 7.865507141778371,
#   'restaurant_price_index': 23.500822610108937},
#  {'city_id': 3540,
#   'city_name': 'Caracas',
#   'country': 'Venezuela',
#   'cpi_and_rent_index': 18.19813124061145,
#   'cpi_index': 27.663789813533846,
#   'groceries_index': 29.32302305283975,
#   'purchasing_power_incl_rent_index': 2.3634589267409045,
#   'rent_index': 7.866483058112254,
#   'restaurant_price_index': 24.228025075947844},
#  {'city_id': 4049,
#   'city_name': 'Pune',
#   'country': 'India',
#   'cpi_and_rent_index': 17.881305029966285,
#   'cpi_index': 27.55893638087587,
#   'groceries_index': 27.49209094771363,
#   'purchasing_power_incl_rent_index': 63.73945493797852,
#   'rent_index': 7.318291206126988,
#   'restaurant_price_index': 22.63111510046844},
#  {'city_id': 8068,
#   'city_name': 'Noida',
#   'country': 'India',
#   'cpi_and_rent_index': 17.171269436875647,
#   'cpi_index': 27.48528241821912,
#   'groceries_index': 24.450289851503378,
#   'purchasing_power_incl_rent_index': 66.8942275291113,
#   'rent_index': 5.913653006699341,
#   'restaurant_price_index': 22.46227141495836},
#  {'city_id': 6946,
#   'city_name': 'Bishkek',
#   'country': 'Kyrgyzstan',
#   'cpi_and_rent_index': 18.698080011309173,
#   'cpi_index': 27.41855545105778,
#   'groceries_index': 24.026565910834908,
#   'purchasing_power_incl_rent_index': 24.6590292252094,
#   'rent_index': 9.179789917333034,
#   'restaurant_price_index': 22.119779278261284},
#  {'city_id': 4058,
#   'city_name': 'Thane',
#   'country': 'India',
#   'cpi_and_rent_index': 18.53406554459606,
#   'cpi_index': 27.271471310988773,
#   'groceries_index': 26.264962212640174,
#   'purchasing_power_incl_rent_index': 58.36406419448789,
#   'rent_index': 8.997296210411328,
#   'restaurant_price_index': 22.798371282317827},
#  {'city_id': 4008,
#   'city_name': 'Bangalore',
#   'country': 'India',
#   'cpi_and_rent_index': 18.36436399146148,
#   'cpi_index': 27.064141097662414,
#   'groceries_index': 27.04154025382784,
#   'purchasing_power_incl_rent_index': 68.05685834571538,
#   'rent_index': 8.868665870197129,
#   'restaurant_price_index': 20.667927082502914},
#  {'city_id': 7329,
#   'city_name': 'Tashkent',
#   'country': 'Uzbekistan',
#   'cpi_and_rent_index': 17.62655307633815,
#   'cpi_index': 26.84932576954039,
#   'groceries_index': 22.610475463400416,
#   'purchasing_power_incl_rent_index': 25.047458327917,
#   'rent_index': 7.560011799864911,
#   'restaurant_price_index': 21.649285618309023},
#  {'city_id': 4025,
#   'city_name': 'Indore',
#   'country': 'India',
#   'cpi_and_rent_index': 15.377734844589016,
#   'cpi_index': 25.80021957084125,
#   'groceries_index': 26.666157939342106,
#   'purchasing_power_incl_rent_index': 43.331541286623434,
#   'rent_index': 4.001722858783335,
#   'restaurant_price_index': 16.345844383864048},
#  {'city_id': 9106,
#   'city_name': 'Goa',
#   'country': 'India',
#   'cpi_and_rent_index': 16.18711035088038,
#   'cpi_index': 25.690081994853074,
#   'groceries_index': 25.53182405806621,
#   'purchasing_power_incl_rent_index': 44.22674920816153,
#   'rent_index': 5.814735417069556,
#   'restaurant_price_index': 23.758707510108408},
#  {'city_id': 4002,
#   'city_name': 'Ahmedabad',
#   'country': 'India',
#   'cpi_and_rent_index': 16.724183865763365,
#   'cpi_index': 25.45180868836575,
#   'groceries_index': 25.744460457350783,
#   'purchasing_power_incl_rent_index': 39.01751866499079,
#   'rent_index': 7.198090309640548,
#   'restaurant_price_index': 17.636828110035697},
#  {'city_id': 8374,
#   'city_name': 'Navi Mumbai',
#   'country': 'India',
#   'cpi_and_rent_index': 16.825467363597372,
#   'cpi_index': 25.236600061496024,
#   'groceries_index': 26.297864246522412,
#   'purchasing_power_incl_rent_index': 100.93174402032857,
#   'rent_index': 7.6448210111508565,
#   'restaurant_price_index': 17.766303791899936},
#  {'city_id': 4024,
#   'city_name': 'Hyderabad',
#   'country': 'India',
#   'cpi_and_rent_index': 16.20460624845758,
#   'cpi_index': 25.207762466358645,
#   'groceries_index': 26.13849195880904,
#   'purchasing_power_incl_rent_index': 57.874739887014336,
#   'rent_index': 6.377773613534433,
#   'restaurant_price_index': 16.61099443275387},
#  {'city_id': 4013,
#   'city_name': 'Chennai',
#   'country': 'India',
#   'cpi_and_rent_index': 16.259565892220582,
#   'cpi_index': 25.151036940441397,
#   'groceries_index': 25.787051175225677,
#   'purchasing_power_incl_rent_index': 53.20384622951019,
#   'rent_index': 6.554636225955102,
#   'restaurant_price_index': 15.60247794913216},
#  {'city_id': 4026,
#   'city_name': 'Jaipur',
#   'country': 'India',
#   'cpi_and_rent_index': 15.378344011906083,
#   'cpi_index': 25.049175730430235,
#   'groceries_index': 23.945352074083427,
#   'purchasing_power_incl_rent_index': 55.06095181385673,
#   'rent_index': 4.822751901942839,
#   'restaurant_price_index': 16.609870684834846},
#  {'city_id': 4060,
#   'city_name': 'Vadodara',
#   'country': 'India',
#   'cpi_and_rent_index': 14.709389243060448,
#   'cpi_index': 24.60778717787328,
#   'groceries_index': 25.770843581876573,
#   'purchasing_power_incl_rent_index': 60.503553076030705,
#   'rent_index': 3.905411448487486,
#   'restaurant_price_index': 17.033436207813654},
#  {'city_id': 4021,
#   'city_name': 'Guwahati',
#   'country': 'India',
#   'cpi_and_rent_index': 14.612998268191141,
#   'cpi_index': 24.39809239580918,
#   'groceries_index': 25.73358727743733,
#   'purchasing_power_incl_rent_index': 49.58668907334244,
#   'rent_index': 3.9326901649192147,
#   'restaurant_price_index': 14.827108108863426},
#  {'city_id': 4047,
#   'city_name': 'Patna',
#   'country': 'India',
#   'cpi_and_rent_index': 14.56472857844369,
#   'cpi_index': 24.34956585457439,
#   'groceries_index': 23.443968349525427,
#   'purchasing_power_incl_rent_index': 45.380375829515614,
#   'rent_index': 3.884700825364191,
#   'restaurant_price_index': 18.10601907307786},
#  {'city_id': 4032,
#   'city_name': 'Kolkata',
#   'country': 'India',
#   'cpi_and_rent_index': 15.171133964366804,
#   'cpi_index': 24.213442911876324,
#   'groceries_index': 23.749573101623607,
#   'purchasing_power_incl_rent_index': 45.49865520649265,
#   'rent_index': 5.3015666137783155,
#   'restaurant_price_index': 20.009660825294414},
#  {'city_id': 4052,
#   'city_name': 'Rajkot',
#   'country': 'India',
#   'cpi_and_rent_index': 14.598031638695225,
#   'cpi_index': 24.17374814295451,
#   'groceries_index': 23.842610601743882,
#   'purchasing_power_incl_rent_index': 51.02923420544221,
#   'rent_index': 4.146256597879053,
#   'restaurant_price_index': 17.486129623680494},
#  {'city_id': 7440,
#   'city_name': 'Kochi',
#   'country': 'India',
#   'cpi_and_rent_index': 14.965174970317536,
#   'cpi_index': 24.126300205907697,
#   'groceries_index': 26.342703834647764,
#   'purchasing_power_incl_rent_index': 46.184307006781395,
#   'rent_index': 4.965921124347595,
#   'restaurant_price_index': 14.109370510440112},
#  {'city_id': 4014,
#   'city_name': 'Coimbatore',
#   'country': 'India',
#   'cpi_and_rent_index': 15.01993419457048,
#   'cpi_index': 24.05783230264758,
#   'groceries_index': 25.806752289700647,
#   'purchasing_power_incl_rent_index': 45.222396079339056,
#   'rent_index': 5.155181220166617,
#   'restaurant_price_index': 14.569628450056488},
#  {'city_id': 4057,
#   'city_name': 'Surat',
#   'country': 'India',
#   'cpi_and_rent_index': 14.172896551223351,
#   'cpi_index': 23.704695679478302,
#   'groceries_index': 23.907001196816555,
#   'purchasing_power_incl_rent_index': 48.65050880775316,
#   'rent_index': 3.7690567781415636,
#   'restaurant_price_index': 17.70710465772346},
#  {'city_id': 7051,
#   'city_name': 'Lahore',
#   'country': 'Pakistan',
#   'cpi_and_rent_index': 14.493836198772037,
#   'cpi_index': 23.401693667270045,
#   'groceries_index': 19.587242935464204,
#   'purchasing_power_incl_rent_index': 28.402329962071406,
#   'rent_index': 4.771020959308422,
#   'restaurant_price_index': 17.91917468114112},
#  {'city_id': 4044,
#   'city_name': 'Nagpur',
#   'country': 'India',
#   'cpi_and_rent_index': 14.207947242707169,
#   'cpi_index': 23.350812471209927,
#   'groceries_index': 22.673763964994436,
#   'purchasing_power_incl_rent_index': 63.55183093673573,
#   'rent_index': 4.228623966552701,
#   'restaurant_price_index': 19.635368122142633},
#  {'city_id': 4010,
#   'city_name': 'Bhopal',
#   'country': 'India',
#   'cpi_and_rent_index': 13.757002974940757,
#   'cpi_index': 23.30317086250278,
#   'groceries_index': 22.902204721195286,
#   'purchasing_power_incl_rent_index': 50.013879464282205,
#   'rent_index': 3.3374798804253896,
#   'restaurant_price_index': 15.517291833637877},
#  {'city_id': 4035,
#   'city_name': 'Lucknow (Lakhnau)',
#   'country': 'India',
#   'cpi_and_rent_index': 14.351893810807207,
#   'cpi_index': 23.215657411724646,
#   'groceries_index': 21.337059170585697,
#   'purchasing_power_incl_rent_index': 53.05782671761511,
#   'rent_index': 4.677206477430476,
#   'restaurant_price_index': 18.354979626370273},
#  {'city_id': 4043,
#   'city_name': 'Mysore',
#   'country': 'India',
#   'cpi_and_rent_index': 14.382511250432303,
#   'cpi_index': 23.188233319535897,
#   'groceries_index': 23.886648607113404,
#   'purchasing_power_incl_rent_index': 51.12528961910835,
#   'rent_index': 4.771175524559087,
#   'restaurant_price_index': 15.117543480787287},
#  {'city_id': 7931,
#   'city_name': 'Bhubaneswar',
#   'country': 'India',
#   'cpi_and_rent_index': 13.883564199304068,
#   'cpi_index': 23.043720514670877,
#   'groceries_index': 24.577448496887637,
#   'purchasing_power_incl_rent_index': 57.68754404286391,
#   'rent_index': 3.88536791766391,
#   'restaurant_price_index': 13.2270491958569},
#  {'city_id': 7048,
#   'city_name': 'Karachi',
#   'country': 'Pakistan',
#   'cpi_and_rent_index': 14.186729682976825,
#   'cpi_index': 23.006818190691476,
#   'groceries_index': 19.959474607208065,
#   'purchasing_power_incl_rent_index': 29.28107662726292,
#   'rent_index': 4.55971316868076,
#   'restaurant_price_index': 19.163588632072774},
#  {'city_id': 7043,
#   'city_name': 'Islamabad',
#   'country': 'Pakistan',
#   'cpi_and_rent_index': 14.796699034076083,
#   'cpi_index': 22.850524689787218,
#   'groceries_index': 22.14514443087564,
#   'purchasing_power_incl_rent_index': 29.651434132390026,
#   'rent_index': 6.0060488582897875,
#   'restaurant_price_index': 17.179796948866493},
#  {'city_id': 4063,
#   'city_name': 'Vijayawada',
#   'country': 'India',
#   'cpi_and_rent_index': 14.006555038296037,
#   'cpi_index': 22.199531037737447,
#   'groceries_index': 22.902692893853764,
#   'purchasing_power_incl_rent_index': 47.38956962609125,
#   'rent_index': 5.064023999195321,
#   'restaurant_price_index': 13.133506497452702},
#  {'city_id': 4064,
#   'city_name': 'Visakhapatnam',
#   'country': 'India',
#   'cpi_and_rent_index': 12.904417196725761,
#   'cpi_index': 20.978264315328918,
#   'groceries_index': 21.296883193281218,
#   'purchasing_power_incl_rent_index': 52.058774854910375,
#   'rent_index': 4.091913844099663,
#   'restaurant_price_index': 13.460438491864926},
#  {'city_id': 7473,
#   'city_name': 'Thiruvananthapuram',
#   'country': 'India',
#   'cpi_and_rent_index': 12.36402147188901,
#   'cpi_index': 19.689978053526847,
#   'groceries_index': 20.198439419962543,
#   'purchasing_power_incl_rent_index': 62.38824892986656,
#   'rent_index': 4.36783130523075,
#   'restaurant_price_index': 10.6699561213523}]

# %%
country_us = []
coli = []
city = []

# %%
response = get_coli_json(api_key)
for r in response:
    if r["country"] == "United States":
        #rank.append(i),
        country_us.append(r["country"])
        coli.append(r["cpi_index"])
        city.append(r["city_name"])

# %%
rank = numpy.arange(1, len(country_us)+1, dtype = list)
len(rank)
# Out:
# 58

# %%
len(country_us)
# Out:
# 58

# %%
raw_data = {
    "Rank": rank,
    "Country": country_us,
    "City": city,
    "Cost Of Living Index": coli   
}

d = pd.DataFrame(raw_data)
df_COLI = d.set_index("Rank")
df_COLI.head()
# Out:
#             Country               City  Cost Of Living Index
# Rank
# 1     United States       New York, NY            100.000000
# 2     United States  San Francisco, CA             91.466340
# 3     United States      Anchorage, AK             91.294352
# 4     United States       Honolulu, HI             89.633705
# 5     United States       Brooklyn, NY             88.758583

# %%
df_COLI.to_csv("Output_Data/COLI.csv")

# %%
df_COLI.count()
# Out:
# Country                 58
# City                    58
# Cost Of Living Index    58
# dtype: int64
