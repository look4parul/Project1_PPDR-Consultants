# %%
# importing dependencies 
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
from indeed import IndeedClient
from config import publisher_key
import requests
import bs4
import re
from html.parser import HTMLParser
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-192-13dbe513ac32> in <module>
#       2
#       3 import requests
# ----> 4 import bs4
#       5 import re
#       6 from html.parser import HTMLParser
#
# ModuleNotFoundError: No module named 'bs4'

# %%
def get_job_data(key, start, location):
    client = IndeedClient(publisher = key)
    parameters = {'q' : "title:data (science OR scientist)",
                  'l' : location,
                  'sort' : "date",
                  'fromage' : "119",
                  'toage' : "0",
                  'limit' : "25",
                  'userip' : "192.168.0.58",
                  'useragent' : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6)",
                  'start': start
                 }
    search_results = client.search(**parameters)
    jobs_df = pd.DataFrame(search_results['results'])
    return jobs_df

# %%
# defining a list of cities(locations) to be used for analysis
cities = ['United States']

# %%
# calling the function to find the total number of 'data' related jobs posted on Indeed.com in last 120 days for 10 cities

total_job_count = 0
city_job_count = 0
for city in cities:
    city_job_count = get_job_count(key=publisher_key, start=0, location=city)
    print(f'Total number of data jobs posted for {city} in last 120 days -', city_job_count)
    total_job_count +=  city_job_count
print('Total number of data job posted on Indeed.com in last 120 days for selected list of cities is: ', total_job_count)

# calling function to get the details of all 'data' related jobs posted on Indeed.com in last 120 days for 10 cities

# storing it in a dataframe

data_jobs_df = pd.DataFrame()
for city in cities:
    start = 0
    count = 0
    city_job_count = get_job_count(key=publisher_key, start=0, location=city)
    print(f'Total number of data jobs posted for {city} in last 120 days -', city_job_count)
    count = (city_job_count // 25) + 1  
    for i in range(0, count):
        print(i, '-', start)
        data_jobs = get_job_data(key=publisher_key, start=start, location=city)
        data_jobs_df = data_jobs_df.append(data_jobs, ignore_index=True)
        start += 25
data_jobs_df.head(5)
data_jobs_df.to_csv('../data/david_f_indeed_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f33b0ba045cb> in <module>
#       4 city_job_count = 0
#       5 for city in cities:
# ----> 6     city_job_count = get_job_count(key=publisher_key, start=0, location=city)
#       7     print(f'Total number of data jobs posted for {city} in last 120 days -', city_job_count)
#       8     total_job_count +=  city_job_count
#
# NameError: name 'get_job_count' is not defined

# %%
path = "indeed_data.csv"

indeed_df = pd.read_csv(path)
indeed_df
# Out:
#      Unnamed: 0                          jobtitle  \
# 0             0                    Data Scientist
# 1             1                    Data Scientist
# 2             2             Senior Data Scientist
# 3             3                    Data Scientist
# 4             4  Data & Customer Insights Analyst
# ..          ...                               ...
# 970         970         Data Scientist, Marketing
# 971         971             Senior Data Scientist
# 972         972                      Data Analyst
# 973         973             Senior Data Scientist
# 974         974   Data Privacy and Policy Officer
#
#                                           company           city state  \
# 0                                           AETNA       Hartford    CT
# 1                                       Microsoft        Redmond    WA
# 2                                         true[x]    Los Angeles    CA
# 3        Social Science Research Solutions (SSRS)     Glen Mills    PA
# 4                            Forum Communications          Fargo    ND
# ..                                            ...            ...   ...
# 970                                         Ricoh        Chicago    IL
# 971                                 X-Mode Social         Reston    VA
# 972                                   Pointillist         Boston    MA
# 973                                       Patreon  San Francisco    CA
# 974  New Jersey Department of Law & Public Safety        Trenton    NJ
#
#     country language  formattedLocation  \
# 0        US       en       Hartford, CT
# 1        US       en        Redmond, WA
# 2        US       en    Los Angeles, CA
# 3        US       en     Glen Mills, PA
# 4        US       en          Fargo, ND
# ..      ...      ...                ...
# 970      US       en        Chicago, IL
# 971      US       en         Reston, VA
# 972      US       en         Boston, MA
# 973      US       en  San Francisco, CA
# 974      US       en        Trenton, NJ
#
#                                        source                           date  \
# 0                                       Aetna  Sat, 11 Jan 2020 15:20:59 GMT
# 1                                   Microsoft  Sat, 11 Jan 2020 13:14:30 GMT
# 2                                      Disney  Sat, 11 Jan 2020 14:31:08 GMT
# 3    Social Science Research Solutions (SSRS)  Sat, 11 Jan 2020 14:22:56 GMT
# 4                        Forum Communications  Sat, 11 Jan 2020 10:37:30 GMT
# ..                                        ...                            ...
# 970                                     Ricoh  Wed, 08 Jan 2020 00:24:43 GMT
# 971                             X-Mode Social  Tue, 07 Jan 2020 18:55:09 GMT
# 972                                    Indeed  Wed, 08 Jan 2020 02:12:25 GMT
# 973                                   Patreon  Tue, 07 Jan 2020 22:36:55 GMT
# 974                                    Indeed  Wed, 08 Jan 2020 02:38:52 GMT
#
#                                                snippet  \
# 0    Minimum one year of <b>data</b> <b>science</b>...
# 1    4+ years of <b>data</b> <b>science</b>, analyt...
# 2    The Senior <b>Data</b> <b>Scientist</b> will b...
# 3    Develop <b>data</b> visualizations to capture ...
# 4    Continuously analyze <b>data</b> throughout th...
# ..                                                 ...
# 970  The <b>Data</b> <b>Scientist</b> uses a variet...
# 971  Develop custom <b>data</b> models and algorith...
# 972  Take full responsibility for the <b>data</b> a...
# 973  To support this growth, Patreon is looking for...
# 974  Classifies <b>data</b> assets according to <b>...
#
#                                                    url  \
# 0    http://www.indeed.com/viewjob?jk=43194fbf78499...
# 1    http://www.indeed.com/viewjob?jk=f737890c10ca9...
# 2    http://www.indeed.com/viewjob?jk=6382ca0dce4fb...
# 3    http://www.indeed.com/viewjob?jk=449135dd3e0f8...
# 4    http://www.indeed.com/viewjob?jk=c7fc0f64a4486...
# ..                                                 ...
# 970  http://www.indeed.com/viewjob?jk=668d34193a23d...
# 971  http://www.indeed.com/viewjob?jk=5602c51cd304c...
# 972  http://www.indeed.com/viewjob?jk=052d25570dd9a...
# 973  http://www.indeed.com/viewjob?jk=316f497845d1f...
# 974  http://www.indeed.com/viewjob?jk=efb48c6253f75...
#
#                   onmousedown            jobkey  sponsored  expired  \
# 0    indeed_clk(this,'2707');  43194fbf78499119      False    False
# 1    indeed_clk(this,'2707');  f737890c10ca957a      False    False
# 2    indeed_clk(this,'2707');  6382ca0dce4fb82f      False    False
# 3    indeed_clk(this,'2707');  449135dd3e0f8cdd      False    False
# 4    indeed_clk(this,'2707');  c7fc0f64a44865d7      False    False
# ..                        ...               ...        ...      ...
# 970  indeed_clk(this,'9458');  668d34193a23ddef      False    False
# 971  indeed_clk(this,'9458');  5602c51cd304cd42      False    False
# 972  indeed_clk(this,'9458');  052d25570dd9aa0e      False    False
# 973  indeed_clk(this,'9458');  316f497845d1f29e      False    False
# 974  indeed_clk(this,'9458');  efb48c6253f75ce4      False    False
#
#      indeedApply  formattedLocationFull formattedRelativeTime  stations
# 0          False     Hartford, CT 06156            1 hour ago       NaN
# 1          False            Redmond, WA           3 hours ago       NaN
# 2          False  Los Angeles, CA 90049           2 hours ago       NaN
# 3          False         Glen Mills, PA           2 hours ago       NaN
# 4          False        Fargo, ND 58102           5 hours ago       NaN
# ..           ...                    ...                   ...       ...
# 970        False      Chicago, IL 60606            3 days ago       NaN
# 971         True       Reston, VA 20190            3 days ago       NaN
# 972         True       Boston, MA 02210            3 days ago       NaN
# 973         True      San Francisco, CA            3 days ago       NaN
# 974         True            Trenton, NJ            3 days ago       NaN
#
# [975 rows x 20 columns]

# %%
indeed_df.drop("onmousedown", axis=1, inplace=True)

# %%
indeed_df.drop("indeedApply", axis=1, inplace=True)

# %%
indeed_df.drop("expired", axis=1, inplace=True)

# %%
indeed_df.drop("formattedLocationFull", axis=1, inplace=True)

# %%
indeed_df
# Out:
#      Unnamed: 0                          jobtitle  \
# 0             0                    Data Scientist
# 1             1                    Data Scientist
# 2             2             Senior Data Scientist
# 3             3                    Data Scientist
# 4             4  Data & Customer Insights Analyst
# ..          ...                               ...
# 970         970         Data Scientist, Marketing
# 971         971             Senior Data Scientist
# 972         972                      Data Analyst
# 973         973             Senior Data Scientist
# 974         974   Data Privacy and Policy Officer
#
#                                           company           city state  \
# 0                                           AETNA       Hartford    CT
# 1                                       Microsoft        Redmond    WA
# 2                                         true[x]    Los Angeles    CA
# 3        Social Science Research Solutions (SSRS)     Glen Mills    PA
# 4                            Forum Communications          Fargo    ND
# ..                                            ...            ...   ...
# 970                                         Ricoh        Chicago    IL
# 971                                 X-Mode Social         Reston    VA
# 972                                   Pointillist         Boston    MA
# 973                                       Patreon  San Francisco    CA
# 974  New Jersey Department of Law & Public Safety        Trenton    NJ
#
#     country language  formattedLocation  \
# 0        US       en       Hartford, CT
# 1        US       en        Redmond, WA
# 2        US       en    Los Angeles, CA
# 3        US       en     Glen Mills, PA
# 4        US       en          Fargo, ND
# ..      ...      ...                ...
# 970      US       en        Chicago, IL
# 971      US       en         Reston, VA
# 972      US       en         Boston, MA
# 973      US       en  San Francisco, CA
# 974      US       en        Trenton, NJ
#
#                                        source                           date  \
# 0                                       Aetna  Sat, 11 Jan 2020 15:20:59 GMT
# 1                                   Microsoft  Sat, 11 Jan 2020 13:14:30 GMT
# 2                                      Disney  Sat, 11 Jan 2020 14:31:08 GMT
# 3    Social Science Research Solutions (SSRS)  Sat, 11 Jan 2020 14:22:56 GMT
# 4                        Forum Communications  Sat, 11 Jan 2020 10:37:30 GMT
# ..                                        ...                            ...
# 970                                     Ricoh  Wed, 08 Jan 2020 00:24:43 GMT
# 971                             X-Mode Social  Tue, 07 Jan 2020 18:55:09 GMT
# 972                                    Indeed  Wed, 08 Jan 2020 02:12:25 GMT
# 973                                   Patreon  Tue, 07 Jan 2020 22:36:55 GMT
# 974                                    Indeed  Wed, 08 Jan 2020 02:38:52 GMT
#
#                                                snippet            jobkey  \
# 0    Minimum one year of <b>data</b> <b>science</b>...  43194fbf78499119
# 1    4+ years of <b>data</b> <b>science</b>, analyt...  f737890c10ca957a
# 2    The Senior <b>Data</b> <b>Scientist</b> will b...  6382ca0dce4fb82f
# 3    Develop <b>data</b> visualizations to capture ...  449135dd3e0f8cdd
# 4    Continuously analyze <b>data</b> throughout th...  c7fc0f64a44865d7
# ..                                                 ...               ...
# 970  The <b>Data</b> <b>Scientist</b> uses a variet...  668d34193a23ddef
# 971  Develop custom <b>data</b> models and algorith...  5602c51cd304cd42
# 972  Take full responsibility for the <b>data</b> a...  052d25570dd9aa0e
# 973  To support this growth, Patreon is looking for...  316f497845d1f29e
# 974  Classifies <b>data</b> assets according to <b>...  efb48c6253f75ce4
#
#     formattedRelativeTime
# 0              1 hour ago
# 1             3 hours ago
# 2             2 hours ago
# 3             2 hours ago
# 4             5 hours ago
# ..                    ...
# 970            3 days ago
# 971            3 days ago
# 972            3 days ago
# 973            3 days ago
# 974            3 days ago
#
# [975 rows x 13 columns]

# %%
unique_jobtitle = indeed_df['jobtitle'].nunique()

unique_title_df = pd.DataFrame({
    "Total Job Titles":[unique_jobtitle]
})
unique_title_df
# Out:
#    Total Job Titles
# 0               713

# %%
grouped_df = indeed_df.groupby(["formattedLocation"])
unique_df = grouped_df["jobtitle"].count()

unique_cities = unique_df.sort_values(ascending = False)
unique_cities.head(12)

#total_gender = unique_df["formattedLocation"].sum()

#count = unique_df["formattedLocation"].unique()
#percentage = unique_df["formattedLocation"]/ 713

#gender_summary = pd.DataFrame({
        
    #    "Count":count,
   #     "Percentage of Players":percentage
#})

# gender_summary["Percentage of Players"] = gender_summary["Percentage of Players"].map("{:,.2%}".format) 
#gender_summary
# Out:
# formattedLocation
# New York, NY         52
# San Francisco, CA    29
# Seattle, WA          27
# Mountain View, CA    22
# Boston, MA           21
# Chicago, IL          21
# Austin, TX           20
# United States        20
# Charlotte, NC        20
# Washington, DC       17
# Atlanta, GA          17
# Reston, VA           15
# Name: jobtitle, dtype: int64

# %%
indeed_df["snippet"]
# Out:
# 0      Minimum one year of <b>data</b> <b>science</b>...
# 1      4+ years of <b>data</b> <b>science</b>, analyt...
# 2      The Senior <b>Data</b> <b>Scientist</b> will b...
# 3      Develop <b>data</b> visualizations to capture ...
# 4      Continuously analyze <b>data</b> throughout th...
#                              ...
# 970    The <b>Data</b> <b>Scientist</b> uses a variet...
# 971    Develop custom <b>data</b> models and algorith...
# 972    Take full responsibility for the <b>data</b> a...
# 973    To support this growth, Patreon is looking for...
# 974    Classifies <b>data</b> assets according to <b>...
# Name: snippet, Length: 975, dtype: object

# %%
def has_bachelor(s):
    return (
        bool(re.search(r"bachelors?'?\s?", s, re.IGNORECASE)) or
        bool(re.search(r"\sB\.?A\.?\s", s, re.IGNORECASE)) or
        bool(re.search(r"\sB\.?S\.?\s", s, re.IGNORECASE))
    )

def has_masters(s):
    return (
        bool(re.search(r"masters?'?s?\s", s, re.IGNORECASE)) or
        bool(re.search(r"\sM\.?A\.?\s", s, re.IGNORECASE)) or
        bool(re.search(r"\sM\.?S\.?\s", s, re.IGNORECASE)) or
        bool(re.search(r"M\.?B\.?A\.?\s", s, re.IGNORECASE))
    )

def has_phd(s):
    return(
        (bool(re.search(r"Ph\.?d", s, re.IGNORECASE))) 
    )

education_df = pd.DataFrame({
    "Bachelor's": indeed_df["snippet"].apply(has_bachelor).value_counts(())[1],
    "Master's": indeed_df["snippet"].apply(has_masters).value_counts(())[1],
    "Phd": indeed_df["snippet"].apply(has_phd).value_counts(())[1],

},index=["Count"])
education_df.plot(kind='bar')
education_df
# Out:
#        Bachelor's  Master's  Phd
# Count          77        42    9

# %%
for snippet in indeed_df[indeed_df["snippet"].apply(has_bachelor)]["snippet"].values:
# Out:
#   File "<ipython-input-192-891ab9b2f3ad>", line 1
#     for snippet in indeed_df[indeed_df["snippet"].apply(has_bachelor)]["snippet"].values:
#                                                                                          ^
# SyntaxError: unexpected EOF while parsing

# %%
indeed_df["snippet"].apply(lambda s: bool(re.search(r"B.A.", s, re.IGNORECASE))).value_counts()
# Out:
# False    960
# True      15
# Name: snippet, dtype: int64

# %%
indeed_df["snippet"].apply(lambda s: bool(re.search(r"master'?s?", s, re.IGNORECASE))).value_counts()
# Out:
# False    925
# True      50
# Name: snippet, dtype: int64
